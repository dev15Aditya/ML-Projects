# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snd

# %%
df = pd.read_csv('Car details v3.csv')
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
df.fuel.value_counts()
# Out:
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: fuel, dtype: int64

# %%
df.fuel.value_counts(normalize= True)
# Out:
# Diesel    0.541585
# Petrol    0.446727
# CNG       0.007013
# LPG       0.004675
# Name: fuel, dtype: float64

# %%
df.fuel.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.fuel.value_counts(normalize= True).plot.pie()
plt.show()

# %%
df.seller_type.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.seller_type.value_counts(normalize= True).plot.pie()
plt.show()

# %%
df.transmission.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.transmission.value_counts(normalize= True).plot.pie()
plt.show()

# %%
df.owner.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.owner.value_counts(normalize= True).plot.pie()
plt.show()

# %% [markdown]
# * Below this every univariate analysis on given data is useless.
# * So we will not consider it

# %%
df.mileage.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.mileage.value_counts(normalize= True).plot.pie()
plt.show()

# %%
df.engine.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.engine.value_counts(normalize= True).plot.pie()
plt.show()

# %%
df.max_power.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.max_power.value_counts(normalize= True).plot.pie()
plt.show()

# %%
df.torque.value_counts(normalize= True).plot.barh()
plt.show()

# %%
df.torque.value_counts(normalize= True).plot.pie()
plt.show()
